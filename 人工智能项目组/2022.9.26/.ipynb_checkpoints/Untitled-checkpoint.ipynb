# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('wpbc.csv')
data.head(n = 10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %% [markdown]
# 项目目的:
#     利用当前的疾病数据集进行训练并保存模型，然后利用新数据预测一个人是否得了乳腺癌
#     良性/恶行 0 1二分类任务
# 任务流程:
#     1.加载数据，观察数据(多角度)
#     2.针对问题提出合适的算法解决问题(逻辑回归)
#     3.数据集分裂(训练集与测试集)
#     4.模型训练(逻辑回归)
#     5.建模结果分析
#     6.调节参数与采样方案对比

# %%
#样本是否均衡

# 如果样本不均衡怎么办? 
# 样本均衡可以省略....

# %%
count_target = pd.value_counts(data['target'],sort=True).sort_index()
count_target.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 问题一 正负样本并不均衡（待解决）
# 问题二 属性与属性之间值差距较大（解决）

# %%
# 数据标准化
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20304/281521461.py in <module>
#       1 # 数据标准化
# ----> 2 from sklearn.preprocessing import StandardScaler
#
# E:\Anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# E:\Anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# E:\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      21
#      22 from .murmurhash import murmurhash3_32
# ...

# %%
# 任务：安装sklearn库

# %%
# 原数据训练（对照实验的原始组）不解决上述两个问题
X = data.iloc[:,data.colums != 'target']
y = data.iloc[:,data.colums == 'target']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14728/3517544525.py in <module>
#       1 # 原数据训练（对照实验的原始组）不解决上述两个问题
# ----> 2 X = data.iloc[:,data.colums != 'target']
#       3 X
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
# 数据分裂（分裂成训练集和测试集）
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
print('训练集的样本数量：',len(X_train))
print('测试集的样本数量：',lenn(X_test))

# %%
# 模型训练
from sklearn.linear_model import LogisticRegressiono
lr = LogisticRegressiono() # 实例化这个LogisticRegressiono这个模型
lr.fit(X_train,y_train)

# %%
# 预测
y_pred = lr.predict(X_test)

# %%
# 给定评估指标

from sklearn.metrics import recall_score
recall_acc = recall_score(y_test,y_pred)

# %%
recall_acc

# %% [markdown]
# ## 总结
# 1.拿到数据之后先观察数据是否出现问题(样本不均衡并且属性之间数值较大)
#     样本不均衡是否可以让他样本均衡?怎样均衡(采样策略)
#
# 2.数据预处理(是否有空值存在，如果有怎么办)
#     如果有空值，我们选择插入值还是删除值呢? ? ?
#
# 3.模型究竟要选哪一种(逻辑回归)
#     模型训练怎样调节参数
