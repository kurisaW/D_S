# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# %%
data = load_digits()
pics = data['data']
nums_pic = pics[899]
nums = nums_pic.reshape((8,8))

# %%
# 聚类任务
X = data['data']

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

scores = []
for k in range(2,15):
    labels = KMeans(n_clusters=k).fit(X).labels_
    score = metrics.silhouette_score(X,labels)
    scores.append(score)
plt.plot(range(2,15),scores)

# %%
SSE = []  # 存放每次结果的误差平方和
for k in range(2,15):
    estimator = KMeans(n_clusters=k)  # 构造聚类器
    estimator.fit(X)
    SSE.append(estimator.inertia_) # estimator.inertia_获取聚类准则的总和
x = range(2,15)
plt.plot(x,SSE,'o-')

# %%
km = KMeans(n_clusters=9)
km.fit(X)
# Out:
# KMeans(n_clusters=9)

# %%
import joblib
joblib.dump(km,'mnist.pkl')
# Out:
# ['mnist.pkl']

# %%
from PIL import Image
pic = Image.open('./002.jpg').convert('L')
pic_array = np.asarray(pic)
new_pic = pic_array.flatten().reshape(1,-1)
# 导入模型
models = joblib.load('mnist.pkl')
models.predict(new_pic)
# Out:
# array([1])

# %%
from PIL import Image
pic = Image.open('./002.jpg').convert('L')
pic_array = np.asarray(pic)
# pic_array.shape
plt.imshow(pic_array)

# %%
import tensorflow as tf
import joblib

# %%
model = ('./mnist.pkl')
