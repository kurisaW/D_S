# %%
import json
import requests

# %%
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36',
    'Cookie':'_lxsdk_cuid=16b69a48a56c8-0ddef7fa7977ea-37c143e-144000-16b69a48a56c8; mtcdn=K; _hc.v=fdab2d0a-27a7-124c-68bb-cab5d15c0425.1655293130; uuid=57297cf2793540eba61b.1655720119.1.0.0; _lx_utm=utm_source=bing&utm_medium=organic; lt=2_ysPTdvYe0V0IVbZIRK1sT0KtAAAAAAexIAAMubw6NZKQuFTJvGjsf-HuL8xaXVVgrXTeOiENdnEY2jW5HBY9-lzwD-BHR0uci_Wg; u=2436196182; n=哈娃娃都被占了; token2=2_ysPTdvYe0V0IVbZIRK1sT0KtAAAAAAexIAAMubw6NZKQuFTJvGjsf-HuL8xaXVVgrXTeOiENdnEY2jW5HBY9-lzwD-BHR0uci_Wg; unc=哈娃娃都被占了; ci=105; rvct=105,1; __mta=151270662.1613989639322.1641801282327.1655720220812.8; client-id=1cc3e2fc-e752-46d0-8c8d-a11a3f4d33f9; _lxsdk=16b69a48a56c8-0ddef7fa7977ea-37c143e-144000-16b69a48a56c8; _lxsdk_s=181809c0e79-292-b85-e17||29; firstTime=1655720241815; lat=45.771608; lng=126.620226',
}

# 源码采集
def codes():
    for page_num in range(0,20,10):
        full_url = 'https://hrb.meituan.com/meishi/api/poi/getMerchantComment?uuid=57297cf2793540eba61b.1655720119.1.0.0&platform=1&partner=126&originUrl=https%3A%2F%2Fhrb.meituan.com%2Fmeishi%2F2061927%2F&riskLevel=1&optimusCode=10&id=2061927&userId=2436196182&offset={}&pageSize=10&sortType=1&tag'.format(page_num)
        jsons = requests.get(full_url,headers=headers)
        makeData(jsons.text)

# 源码清洗
def makeData(jsons):
    print(jsons)

# 信息保存
def stoData():
    pass

if __name__ == '__main__':
    codes()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10852/3597799807.py in <module>
#      20
#      21 if __name__ == '__main__':
# ---> 22     codes()
#
# ~\AppData\Local\Temp/ipykernel_10852/3597799807.py in codes()
#       8     for page_num in range(0,20,10):
#       9         full_url = 'https://hrb.meituan.com/meishi/api/poi/getMerchantComment?uuid=57297cf2793540eba61b.1655720119.1.0.0&platform=1&partner=126&originUrl=https%3A%2F%2Fhrb.meituan.com%2Fmeishi%2F2061927%2F&riskLevel=1&optimusCode=10&id=2061927&userId=2436196182&offset={}&pageSize=10&sortType=1&tag'.format(page_num)
# ---> 10         jsons = requests.get(full_url,headers=headers)
#      11         makeData(jsons.text)
#      12
#
# D:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ...
